# %%
Student_name = str(input("Enter your name:"))
Age = int(input("Enter your age"))
Place = str(input("Enter your place"))

Python_Mark = int(input("Enter your python mark"))
English_Mark = int(input("Enter your english mark"))
Maths_Mark = int(input("Enter your maths mark"))

Total_Mark = Python_Mark + English_Mark + Maths_Mark
Average_Mark = Total_Mark / 3

print("Student Name:", Student_name)
print("Age:", Age)
print("Place:", Place)
print("Total Mark:", Total_Mark)
print("Average Mark:", Average_Mark)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 Student_name = str(input("Enter your name:"))
# ----> 2 Age = int(input("Enter your age"))
#       3 Place = str(input("Enter your place"))
#       4
#       5 Python_Mark = int(input("Enter your python mark"))
#
# TypeError: 'int' object is not callable

# %%
a = 10
b =20

if a>b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 20
float_num = float(a)
print(a)
print(float_num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 a = 20
# ----> 2 float_num = float(a)
#       3 print(a)
#       4 print(float_num)
#
# TypeError: 'float' object is not callable

# %%
a = 20
float_num = float(a)
print(a)
print(float_num)
# Out:
# 20
# 20.0

# %%
number = 8943103140
mark = 96.5
name = "shoib"
is_a_student = True

print(type(number))
print(type(mark))
print(type(name))
print(type(is_a_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 10
b = 20
a+b
# Out:
# 30

# %%
print("Welcome <shoib>")
# Out:
# Welcome <shoib>

# %%
a = int(input("enter the first number"))
b = int(input("enter the second number"))
print(a,b)
# Out:
# 5 6

# %%
place = str(input("enter your place"))
print(place)
# Out:
# tanur

# %%
age = int(input("enter your age"))
print(age)
# Out:
# 22

# %%
name = str(input("enter your name:"))
print(name)
# Out:
# adhii
